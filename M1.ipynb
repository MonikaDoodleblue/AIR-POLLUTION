# %% [markdown]
# # Data Preprocessing:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv('city_day.csv')

# %%
data
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  01-01-2015    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  02-01-2015    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  03-01-2015    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  04-01-2015    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  05-01-2015    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  27-06-2020  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  28-06-2020  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  29-06-2020  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  30-06-2020  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  01-07-2020  15.00  66.00   0.40  26.85  14.05   5.20
#
#           CO    SO2      O3  Benzene  Toluene  Xylene   AQI    AQI_Bucket
# 0       0.92  27.64  133.36     0.00     0.02    0.00   NaN           NaN
# 1       0.97  24.55   34.06     3.68     5.50    3.77   NaN           NaN
# 2      17.40  29.07   30.70     6.80    16.40    2.25   NaN           NaN
# 3       1.70  18.59   36.08     4.43    10.14    1.00   NaN           NaN
# 4      22.10  39.33   39.31     7.01    18.89    2.78   NaN           NaN
# ...      ...    ...     ...      ...      ...     ...   ...           ...
# 29526   0.47   8.55   23.30     2.24    12.07    0.73  41.0          Good
# 29527   0.52  12.72   30.14     0.74     2.21    0.38  70.0  Satisfactory
# 29528   0.48   8.42   30.96     0.01     0.01    0.00  68.0  Satisfactory
# 29529   0.52   9.84   28.30     0.00     0.00    0.00  54.0  Satisfactory
# 29530   0.59   2.10   17.05      NaN      NaN     NaN  50.0          Good
#
# [29531 rows x 16 columns]

# %% [markdown]
# Before removing the null data

# %%
data.shape
# Out:
# (29531, 16)

# %%
data.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# After removing the null data

# %%
df = data.dropna()

# %%
df.shape
# Out:
# (6236, 16)

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6236 entries, 2123 to 29529
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        6236 non-null   object
#  1   Date        6236 non-null   object
#  2   PM2.5       6236 non-null   float64
#  3   PM10        6236 non-null   float64
#  4   NO          6236 non-null   float64
#  5   NO2         6236 non-null   float64
#  6   NOx         6236 non-null   float64
#  7   NH3         6236 non-null   float64
#  8   CO          6236 non-null   float64
#  9   SO2         6236 non-null   float64
#  10  O3          6236 non-null   float64
#  11  Benzene     6236 non-null   float64
#  12  Toluene     6236 non-null   float64
#  13  Xylene      6236 non-null   float64
#  14  AQI         6236 non-null   float64
#  15  AQI_Bucket  6236 non-null   object
# dtypes: float64(13), object(3)
# memory usage: 828.2+ KB

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# 2123     False
# 2124     False
# 2125     False
# 2126     False
# 2127     False
#          ...
# 29525    False
# 29526    False
# 29527    False
# 29528    False
# 29529    False
# Length: 6236, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              PM2.5         PM10           NO          NO2          NOx  \
# count  6236.000000  6236.000000  6236.000000  6236.000000  6236.000000
# mean     61.327365   123.418321    17.015191    31.708190    32.448956
# std      53.709682    85.791491    20.037836    18.784041    27.388129
# min       2.000000     7.800000     0.250000     0.170000     0.170000
# 25%      27.927500    66.970000     5.080000    15.977500    14.547500
# 50%      47.490000   103.010000    10.060000    28.900000    24.285000
# 75%      73.442500   150.770000    19.392500    43.632500    39.622500
# max     639.190000   796.880000   159.220000   140.170000   224.090000
#
#                NH3           CO          SO2           O3      Benzene  \
# count  6236.000000  6236.000000  6236.000000  6236.000000  6236.000000
# mean     20.737070     0.984344    11.514426    36.127691     3.700361
# std      16.088215     1.356161     7.166113    19.553695     5.062159
# min       0.120000     0.000000     0.710000     1.550000     0.000000
# 25%      10.390000     0.490000     6.557500    22.357500     0.910000
# 50%      14.690000     0.730000     9.875000    32.540000     2.435000
# 75%      28.545000     1.060000    14.430000    45.512500     4.620000
# max     166.700000    16.230000    70.390000   162.330000    64.440000
#
#            Toluene       Xylene          AQI
# count  6236.000000  6236.000000  6236.000000
# mean     10.323696     2.557439   140.510103
# std      12.287223     4.535060    92.738826
# min       0.000000     0.000000    23.000000
# 25%       2.210000     0.300000    78.000000
# 50%       6.310000     1.250000   112.000000
# 75%      13.040000     3.030000   166.000000
# max     103.000000   125.180000   677.000000

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.City.unique()
# Out:
# array(['Amaravati', 'Amritsar', 'Chandigarh', 'Delhi', 'Gurugram',
#        'Hyderabad', 'Kolkata', 'Patna', 'Visakhapatnam'], dtype=object)

# %%
df['PM2.5'].unique()
# Out:
# array([81.4 , 78.32, 88.76, ...,  7.63, 24.38, 16.64])

# %%
df.Toluene.unique()
# Out:
# array([ 6.5 ,  7.95,  7.63, ..., 11.54, 18.89, 10.26])

# %%
df.NH3.unique()
# Out:
# array([10.72, 10.28, 12.91, ..., 10.62,  8.25, 12.47])

# %%
df.AQI_Bucket.unique()
# Out:
# array(['Moderate', 'Poor', 'Very Poor', 'Satisfactory', 'Good', 'Severe'],
#       dtype=object)

# %%
df.AQI_Bucket.value_counts()
# Out:
# Moderate        2521
# Satisfactory    2079
# Poor             648
# Good             454
# Very Poor        410
# Severe           124
# Name: AQI_Bucket, dtype: int64

# %%
pd.crosstab(df.City,df.AQI_Bucket)
# Out:
# AQI_Bucket     Good  Moderate  Poor  Satisfactory  Severe  Very Poor
# City
# Amaravati       101       191    41           305       0          8
# Amritsar         34       252    49           252       2         47
# Chandigarh       48        66    15           145       0          3
# Delhi             0       360   328           104     117        315
# Gurugram          0        97     2            20       0          0
# Hyderabad       126       810    30           645       4          3
# Kolkata          95        87    71           139       0          2
# Patna             0       103    42            31       1         14
# Visakhapatnam    50       555    70           438       0         18

# %%
pd.crosstab(df.PM10,df.AQI_Bucket)
# Out:
# AQI_Bucket  Good  Moderate  Poor  Satisfactory  Severe  Very Poor
# PM10
# 7.80           0         0     0             1       0          0
# 8.16           0         0     0             1       0          0
# 10.54          0         0     0             1       0          0
# 10.87          1         0     0             0       0          0
# 11.00          1         0     0             0       0          0
# ...          ...       ...   ...           ...     ...        ...
# 654.68         0         0     0             0       1          0
# 706.58         0         0     0             0       1          0
# 743.98         0         0     0             0       1          0
# 761.91         0         0     0             0       1          0
# 796.88         0         0     0             0       1          0
#
# [5399 rows x 6 columns]

# %%
df.corr()
# Out:
#             PM2.5      PM10        NO       NO2       NOx       NH3        CO  \
# PM2.5    1.000000  0.895543  0.604239  0.559055  0.618705  0.582025  0.422486
# PM10     0.895543  1.000000  0.633340  0.625172  0.672993  0.585555  0.395632
# NO       0.604239  0.633340  1.000000  0.527426  0.875593  0.432795  0.292911
# NO2      0.559055  0.625172  0.527426  1.000000  0.692273  0.387388  0.231773
# NOx      0.618705  0.672993  0.875593  0.692273  1.000000  0.411122  0.336048
# NH3      0.582025  0.585555  0.432795  0.387388  0.411122  1.000000  0.449340
# CO       0.422486  0.395632  0.292911  0.231773  0.336048  0.449340  1.000000
# SO2      0.249567  0.280301  0.200964  0.386170  0.192094  0.192573  0.046117
# O3       0.293691  0.306355  0.048602  0.251862  0.083137  0.157271  0.058788
# Benzene  0.203572  0.222376  0.377932  0.246807  0.492704  0.101514  0.107568
# Toluene  0.475935  0.518722  0.541146  0.499104  0.596449  0.323563  0.200851
# Xylene   0.068741  0.092896  0.134869  0.081074  0.183274  0.015100  0.111264
